# 32  Samsung Galaxy Tab A8 Tablet Android 10.5 Poll...       en
# 33  Discover how Walmart transformed the retail as...       en
# 34  #topOferta  Smart TV Samsung 55" Crystal UHD 4...       de
# 35  @ViCustomerCare I received text message at 11....       en
# 36  ✅stock: 2023/05/31 17:00(EST)\n\nSAMSUNG Elect...       en
# 37  #promoção #oferta #samsung Samsung Galaxy M54 ...       pt
# 38  Tá certo isso aqui? 👀\n\n#GalaxyBook3Ultra #Sa...       pt
# 39  Transform your entrance, sales floor and meeti...       en
# 40  #ghana #samsung\n\nSeeing is believing, kindly...       en
# 41  #Samsung #Galaxy #A34 vs. #A33 https://t.co/8d...      und
# 42  I named my phone @shxtou\n#shxtou #shoto #Vtub...       en
# 43  #promoção #oferta  Smart TV Samsung 65" QLED 4...       en
# 44  Screen glass replacement for note9 #samsung #g...       en
# 45  Samsung Galaxy S23 Ultra| THE BEST PHONE SO FA...       en
# 46  #note22 night mode... My back yard...\n#Samsun...       en
# 47  #promoção #oferta  Smart TV Neo QLED Samsung 5...       en
# 48  El Samsung Freestyle es el último proyector de...       es
# 49  Estos son los descuentos que Samsung México pr...       es
# 50  ##Samsung MX-ST90B Sound Tower High Power Audi...       en
# 51  La plataforma de seguridad, que fue presentada...       es
# 52  After weeks of customer care chats and talking...       en
# 53  #promoção #oferta  [Marketplace] Smartphone Sa...       de
# 54  Why #Samsung  why? I have been in constant fol...       en
# 55  😴 Samsung Smart Tv Neo Qled 4k 65" Samsung Qn8...       en
# 56  Look at this cute star striped phone case we j...       en
# 57  #promoção #oferta  Smartphone Samsung Galaxy M...       de
# 58  #promoção #oferta  Smartphone Samsung Galaxy M...       de
# 59  Sky has no limit 🥴\n#s22 \n#samsung \n#galaxy ...       en
#
#            Username  ReplyCount  RetweetCount  LikeCount  Source
# 0         Compao_mx           0             0          0     NaN  \
# 1       TinformasBo           0             0          0     NaN
# 2        jsspursfan           0             0          0     NaN
# 3       TudoCelular           0             0          3     NaN
# 4      stockpriceus           0             0          0     NaN
# 5     _intellismart           0             0          2     NaN
# 6      OfertasShark           0             0          0     NaN
# 7        parentesis           0             0          5     NaN
# 8     _intellismart           0             0          3     NaN
# 9       BLBPhoto_91           0             0          1     NaN
# 10     gears_switch           0             0          0     NaN
# 11  COREpliroforiki           0             0          0     NaN
# 12    productoflife           0             1          3     NaN
# 13   BestGadgetShow           0             0          0     NaN
# 14      watch_akiba           0            16         32     NaN
# 15  ResearchSnipers           0             0          0     NaN
# 16          Tian_A1           0             0          0     NaN
# 17   GeraldJMickoJr           0             0          1     NaN
# 18   ActiveHearing_           0             0          0     NaN
# 19    FredSamsung23           0             0          0     NaN
# 20          Tian_A1           0             0          0     NaN
# 21  emlakkulisicomm           0             0          3     NaN
# 22          Tian_A1           0             0          0     NaN
# 23     stockpriceus           0             0          0     NaN
# 24         ATGizmos           0             1          1     NaN
# 25  mohammadali_im1           0             0          0     NaN
# 26      TudoCelular           0             1         10     NaN
# 27     stockpriceus           0             0          0     NaN
# 28      MusicSuiteC           0             1          3     NaN
# 29  OfertasAmazon87           0             0          2     NaN
# 30      upstractcom           0             0          0     NaN
# 31   Tekuminakama69           2             1          1     NaN
# 32   andreastoolbox           0             0          0     NaN
# 33   ViewTech_Group           0             0          0     NaN
# 34  PromobitOficial           0             0          0     NaN
# 35         NivJay80           1             0          0     NaN
# 36     stockpriceus           0             0          0     NaN
# 37     TopOfertasBR           0             0          0     NaN
# 38          abvscls           0             0          0     NaN
# 39       MktgMelany           0             0          0     NaN
# 40      igoodsghana           0             1          1     NaN
# 41  mohammadali_im1           0             0          0     NaN
# 42         Astarmy2           0             0          0     NaN
# 43  PromobitOficial           0             0          0     NaN
# 44   cellfixgeorgia           0             0          0     NaN
# 45     mrjlwilliams           1             3          5     NaN
# 46         jacobdrj           2             0          9     NaN
# 47  PromobitOficial           0             0          0     NaN
# 48  spain_tech_blog           0             0          0     NaN
# 49        Tecnodiva           0             0          1     NaN
# 50      dealnarwhal           0             0          0     NaN
# 51   CEconomico1997           0             0          0     NaN
# 52    HatimJamnagar           0             0          0     NaN
# 53  PromobitOficial           0             0          1     NaN
# 54    HatimJamnagar           2             0          0     NaN
# 55     OfertasShark           0             0          0     NaN
# 56      LexGStudios           0             0          4     NaN
# 57  PromobitOficial           0             0          0     NaN
# 58  PromobitOficial           0             0          0     NaN
# 59      98_ashirbad           0             0          0     NaN
#
#                                                   Url
# 0   https://twitter.com/Compao_mx/status/166405792...
# 1   https://twitter.com/TinformasBo/status/1664057...
# 2   https://twitter.com/jsspursfan/status/16640568...
# 3   https://twitter.com/TudoCelular/status/1664055...
# 4   https://twitter.com/stockpriceus/status/166405...
# 5   https://twitter.com/_intellismart/status/16640...
# 6   https://twitter.com/OfertasShark/status/166405...
# 7   https://twitter.com/parentesis/status/16640521...
# 8   https://twitter.com/_intellismart/status/16640...
# 9   https://twitter.com/BLBPhoto_91/status/1664050...
# 10  https://twitter.com/gears_switch/status/166405...
# 11  https://twitter.com/COREpliroforiki/status/166...
# 12  https://twitter.com/productoflife/status/16640...
# 13  https://twitter.com/BestGadgetShow/status/1664...
# 14  https://twitter.com/watch_akiba/status/1664046...
# 15  https://twitter.com/ResearchSnipers/status/166...
# 16  https://twitter.com/Tian_A1/status/16640445238...
# 17  https://twitter.com/GeraldJMickoJr/status/1664...
# 18  https://twitter.com/ActiveHearing_/status/1664...
# 19  https://twitter.com/FredSamsung23/status/16640...
# 20  https://twitter.com/Tian_A1/status/16640424557...
# 21  https://twitter.com/emlakkulisicomm/status/166...
# 22  https://twitter.com/Tian_A1/status/16640401226...
# 23  https://twitter.com/stockpriceus/status/166403...
# 24  https://twitter.com/ATGizmos/status/1664038209...
# 25  https://twitter.com/mohammadali_im1/status/166...
# 26  https://twitter.com/TudoCelular/status/1664036...
# 27  https://twitter.com/stockpriceus/status/166403...
# 28  https://twitter.com/MusicSuiteC/status/1664032...
# 29  https://twitter.com/OfertasAmazon87/status/166...
# 30  https://twitter.com/upstractcom/status/1664031...
# 31  https://twitter.com/Tekuminakama69/status/1664...
# 32  https://twitter.com/andreastoolbox/status/1664...
# 33  https://twitter.com/ViewTech_Group/status/1664...
# 34  https://twitter.com/PromobitOficial/status/166...
# 35  https://twitter.com/NivJay80/status/1664029111...
# 36  https://twitter.com/stockpriceus/status/166402...
# 37  https://twitter.com/TopOfertasBR/status/166402...
# 38  https://twitter.com/abvscls/status/16640285953...
# 39  https://twitter.com/MktgMelany/status/16640275...
# 40  https://twitter.com/igoodsghana/status/1664026...
# 41  https://twitter.com/mohammadali_im1/status/166...
# 42  https://twitter.com/Astarmy2/status/1664021789...
# 43  https://twitter.com/PromobitOficial/status/166...
# 44  https://twitter.com/cellfixgeorgia/status/1664...
# 45  https://twitter.com/mrjlwilliams/status/166402...
# 46  https://twitter.com/jacobdrj/status/1664019790...
# 47  https://twitter.com/PromobitOficial/status/166...
# 48  https://twitter.com/spain_tech_blog/status/166...
# 49  https://twitter.com/Tecnodiva/status/166401480...
# 50  https://twitter.com/dealnarwhal/status/1664014...
# 51  https://twitter.com/CEconomico1997/status/1664...
# 52  https://twitter.com/HatimJamnagar/status/16640...
# 53  https://twitter.com/PromobitOficial/status/166...
# 54  https://twitter.com/HatimJamnagar/status/16640...
# 55  https://twitter.com/OfertasShark/status/166400...
# 56  https://twitter.com/LexGStudios/status/1664006...
# 57  https://twitter.com/PromobitOficial/status/166...
# 58  https://twitter.com/PromobitOficial/status/166...
# 59  https://twitter.com/98_ashirbad/status/1664003...

# %%
twt = pd.read_csv('Twitter_data.csv')

#We are only selecting dates and contents which are required for future analysis

twt = twt[[ 'Date', 'Content']]

# %%
twt.head()
# Out:
#                         Date
# 0  2023-05-31 23:55:00+00:00  \
# 1  2023-05-31 23:54:25+00:00
# 2  2023-05-31 23:50:32+00:00
# 3  2023-05-31 23:45:00+00:00
# 4  2023-05-31 23:40:18+00:00
#
#                                              Content
# 0  #HotSale 🔥 en #Compao \n\n📱Samsung Galaxy S23+...
# 1  #KnoxMatrix: 10 años de Knox Security y la vis...
# 2  Took these pictures last night using my tele z...
# 3  E aí, o que acha? 🤔 #TudoCelular #Samsung #Gal...
# 4  ✅stock: 2023/05/31 18:40(EST)\n\nSAMSUNG SR35 ...

# %%
twt.tail()
# Out:
#                          Date
# 55  2023-05-31 20:35:43+00:00  \
# 56  2023-05-31 20:32:35+00:00
# 57  2023-05-31 20:31:02+00:00
# 58  2023-05-31 20:28:02+00:00
# 59  2023-05-31 20:18:11+00:00
#
#                                               Content
# 55  😴 Samsung Smart Tv Neo Qled 4k 65" Samsung Qn8...
# 56  Look at this cute star striped phone case we j...
# 57  #promoção #oferta  Smartphone Samsung Galaxy M...
# 58  #promoção #oferta  Smartphone Samsung Galaxy M...
# 59  Sky has no limit 🥴\n#s22 \n#samsung \n#galaxy ...

# %% [markdown]
# The next step is preprocessing the tweets so that you can avoid noise present in the text.

# %%
from textblob import TextBlob

# %%
#text preprocess for twitter data

twt['Content'] = twt['Content'].str.lstrip('0123456789')

#lower casing

twt['Content'] = twt['Content'].apply(lambda a: " ".join(a.lower() for a in a.split()))

#remove punctuation

twt['Content'] = twt['Content'].str.replace('[^\w\s]','')

#remove stopwords

sw = stopwords.words ('english')

twt['Content'] = twt['Content'].apply(lambda a: " ".join(a for a in a.split() if a not in sw))

#spelling correction

twt['Content'].apply(lambda a: str(TextBlob(a).correct()))
# Out:
# 0     #hostile 🔥 en #company 📱samson galaxy s+ aprov...
# 1     #knoxmatrix: 10 amos de knox security la visio...
# 2     took pictures last night using tell room lens ...
# 3     e a, que ache? 🤔 #tudocelular #samson #galaxyf...
# 4     ✅stock: 2023/05/31 18:40(est) samson sr35 seri...
# 5     need choose more. samson's windfree technology...
# 6     😴 samson spoke 1-door flex 323 l con slim ice ...
# 7     fan de @samsungmexico, est information les con...
# 8     discover samson outdoor signal window display;...
# 9     #road #sky #trees #clouds #grass #mobilephotog...
# 10    keep tablet safe everyday wear tear. get today...
# 11    η samson κατασκευάζει νέο risk για επιχειρήσει...
# 12    mandalorian daily drawing @stevepaulcreations ...
# 13    arcarmour inkstand case s🔥 #samson #samsunggal...
# 14    of：to ssdの期間限定セールが6月1日からスタート、samson 870 qvoシリー...
# 15    galaxy z lip 3 making screens – here’s learned...
# 16    [ http://t.co/keryemow7o ] les #samson ww90t63...
# 17    phone 11 12 13 new oncoming call. is samson s ...
# 18    samson introducing several new hearing inacces...
# 19    need top phone tip? @fearnecotton knows stuff....
# 20    le #samson #galaxy s ultra est le #smartphone ...
# 21    samson galaxy s ultra carrefour'da ok laguna! ...
# 22    le #samson #galaxy s settlement 1 : c'est l'of...
# 23    ✅stock: 2023/05/31 17:40(est) samson 970 eve p...
# 24    vive you+ g announced diversity 6020 http://t....
# 25    #samson #galaxy s: what’s difference? http://t...
# 26    interessante, no é mess?! 📱📊 #tudocelular #sam...
# 27    ✅stock: 2023/05/31 17:20(est) samson 980 pro s...
# 28    cos america’s biggest companies china week els...
# 29    aorta haste un 50% al compare samson tablet a ...
# 30    report: fixed watch 2 dumps samson exynos sons...
# 31    dream phone concept made samson notes bathroom...
# 32    samson galaxy tax a tablet andros 10.5 pollici...
# 33    discover palmar transformed retail associate e...
# 34    #topoferta smart to samson 55" crystal und k t...
# 35    @vicustomercare received text message 11.01 mu...
# 36    ✅stock: 2023/05/31 17:00(est) samson electroni...
# 37    #promoção #opera #samson samson galaxy may g (...
# 38    to carts iss qui? 👀 #galaxybook3ultra #samson ...
# 39    transform entrance, sales floor meeting spaces...
# 40    #than #samson seeing believing, kindly make ti...
# 41    #samson #galaxy #and vs. #and http://t.co/8dwy...
# 42    named phone @shitov #shitov #shot #tube #samso...
# 43    #promoção #opera smart to samson 65" led k moo...
# 44    screen glass replacement note #samson #galaxy ...
# 45    samson galaxy s ultra| best phone far 2023? #g...
# 46    #note night mode... back yard... #samson #phot...
# 47    #promoção #opera smart to neo led samson 55" k...
# 48    el samson freestyle es el último protector del...
# 49    stop son los descuentos que samson mexico pres...
# 50    ##samson my-stab sound tower high power audit ...
# 51    la platform de seguridad, que due presented fo...
# 52    weeks customer care chats talking managers, ge...
# 53    #promoção #opera [marketplace] smartphone sams...
# 54    #samson why? constant follow teach support sam...
# 55    😴 samson smart to neo led k 65" samson qn85c 2...
# 56    look cut star striped phone case posted lexgst...
# 57    #promoção #opera smartphone samson galaxy may ...
# 58    #promoção #opera smartphone samson galaxy may ...
# 59    sky limit 🥴 #s #samson #galaxy http://t.co/bou...
# Name: Content, dtype: object

# %% [markdown]
# After Preprocessing

# %%
twt.head()
# Out:
#                         Date
# 0  2023-05-31 23:55:00+00:00  \
# 1  2023-05-31 23:54:25+00:00
# 2  2023-05-31 23:50:32+00:00
# 3  2023-05-31 23:45:00+00:00
# 4  2023-05-31 23:40:18+00:00
#
#                                              Content
# 0  #hotsale 🔥 en #compao 📱samsung galaxy s23+ apr...
# 1  #knoxmatrix: 10 años de knox security la visió...
# 2  took pictures last night using tele zoom lens ...
# 3  e aí, que acha? 🤔 #tudocelular #samsung #galax...
# 4  ✅stock: 2023/05/31 18:40(est) samsung sr35 ser...

# %%
twt.tail()
# Out:
#                          Date
# 55  2023-05-31 20:35:43+00:00  \
# 56  2023-05-31 20:32:35+00:00
# 57  2023-05-31 20:31:02+00:00
# 58  2023-05-31 20:28:02+00:00
# 59  2023-05-31 20:18:11+00:00
#
#                                               Content
# 55  😴 samsung smart tv neo qled 4k 65" samsung qn8...
# 56  look cute star striped phone case posted lexgs...
# 57  #promoção #oferta smartphone samsung galaxy m5...
# 58  #promoção #oferta smartphone samsung galaxy m1...
# 59  sky limit 🥴 #s22 #samsung #galaxy https://t.co...

# %% [markdown]
# ## Predicting the emotion

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Create a TfidfVectorizer instance

tv = TfidfVectorizer()

Xpredict=twt['Content']
# Transform the preprocessed data into TF-IDF features

X = tv.fit_transform(Xpredict)

# Apply K-means clustering

num_clusters = 5  # Define the number of clusters

n_init = 10  # Set the value of n_init explicitly to suppress the warning

kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=n_init)

cluster_labels = kmeans.fit_predict(X)

# Assign the cluster labels to the 'Emotion' column in twt

twt['Emotion'] = cluster_labels

# Display the updated twt dataframe

twt.head()
# Out:
#                         Date
# 0  2023-05-31 23:55:00+00:00  \
# 1  2023-05-31 23:54:25+00:00
# 2  2023-05-31 23:50:32+00:00
# 3  2023-05-31 23:45:00+00:00
# 4  2023-05-31 23:40:18+00:00
#
#                                              Content  Emotion
# 0  #hotsale 🔥 en #compao 📱samsung galaxy s23+ apr...        1
# 1  #knoxmatrix: 10 años de knox security la visió...        3
# 2  took pictures last night using tele zoom lens ...        2
# 3  e aí, que acha? 🤔 #tudocelular #samsung #galax...        1
# 4  ✅stock: 2023/05/31 18:40(est) samsung sr35 ser...        4

# %%
twt.tail()
# Out:
#                          Date
# 55  2023-05-31 20:35:43+00:00  \
# 56  2023-05-31 20:32:35+00:00
# 57  2023-05-31 20:31:02+00:00
# 58  2023-05-31 20:28:02+00:00
# 59  2023-05-31 20:18:11+00:00
#
#                                               Content  Emotion
# 55  😴 samsung smart tv neo qled 4k 65" samsung qn8...        2
# 56  look cute star striped phone case posted lexgs...        3
# 57  #promoção #oferta smartphone samsung galaxy m5...        1
# 58  #promoção #oferta smartphone samsung galaxy m1...        1
# 59  sky limit 🥴 #s22 #samsung #galaxy https://t.co...        1

# %% [markdown]
# ## Predicting the Sentiment
#
# We predicted emotion using the function that we built earlier. But to predict sentiment, we are using a pretrained model. Let's use the sentiment function from TextBlob. We predict sentiment for each tweet and then aggregate to generate the insights.
#
# The sentiment function has two outputs: polarity and subjectivity.
#
# We concentrate on polarity, which provides the sentiment of that tweet on a scale of -1 to +1. You need to decide the threshold to get the final sentiment. For this,
#
# if the polarity is > 0, then the positive sentiment
#
# if the polarity is < 0, then the negative sentiment
#
# if the polarity is = 0, then neutral sentiment
#
# The following code provides the sentiments against the given input.

# %%
twt['sentiment'] = twt['Content'].apply(lambda a: TextBlob (a). sentiment[0])

def function (value):
    if value['sentiment'] < 0: 
        return 'Negative'
    if value['sentiment'] > 0:
        return 'Positive'
    return 'Neutral'

twt['Sentiment_label'] = twt.apply (lambda a: function(a), axis=1)

twt.head()
# Out:
#                         Date
# 0  2023-05-31 23:55:00+00:00  \
# 1  2023-05-31 23:54:25+00:00
# 2  2023-05-31 23:50:32+00:00
# 3  2023-05-31 23:45:00+00:00
# 4  2023-05-31 23:40:18+00:00
#
#                                              Content  Emotion  sentiment
# 0  #hotsale 🔥 en #compao 📱samsung galaxy s23+ apr...        1        0.0  \
# 1  #knoxmatrix: 10 años de knox security la visió...        3        0.0
# 2  took pictures last night using tele zoom lens ...        2        0.0
# 3  e aí, que acha? 🤔 #tudocelular #samsung #galax...        1        0.0
# 4  ✅stock: 2023/05/31 18:40(est) samsung sr35 ser...        4        0.0
#
#   Sentiment_label
# 0         Neutral
# 1         Neutral
# 2         Neutral
# 3         Neutral
# 4         Neutral

# %%
twt.tail()
# Out:
#                          Date
# 55  2023-05-31 20:35:43+00:00  \
# 56  2023-05-31 20:32:35+00:00
# 57  2023-05-31 20:31:02+00:00
# 58  2023-05-31 20:28:02+00:00
# 59  2023-05-31 20:18:11+00:00
#
#                                               Content  Emotion  sentiment
# 55  😴 samsung smart tv neo qled 4k 65" samsung qn8...        2   0.214286  \
# 56  look cute star striped phone case posted lexgs...        3   0.425000
# 57  #promoção #oferta smartphone samsung galaxy m5...        1   0.000000
# 58  #promoção #oferta smartphone samsung galaxy m1...        1   0.000000
# 59  sky limit 🥴 #s22 #samsung #galaxy https://t.co...        1   0.000000
#
#    Sentiment_label
# 55        Positive
# 56        Positive
# 57         Neutral
# 58         Neutral
# 59         Neutral

# %% [markdown]
# ## Visualization and Insights
#
# We generated emotion and sentiment in the last section. But building the algorithms, predicting emotion and sentiment won't solve the purpose. Instead, you need insights so that businesses can make decisions on that.
#
# This section discusses how to do that using different libraries. The output of the predictive models is visualized through the different graphs. We are leveraging libraries like Plotly and Matplotlib.
#
# First, let's visualize the sentiments. This is done by a pie graph, which gives detailed insight. The cufflinks library generates the graph.

# %%
import chart_studio.plotly as py

import plotly as ply

import cufflinks as cf

from plotly.graph_objs import *

from plotly.offline import *

init_notebook_mode (connected=True)

cf.set_config_file(offline=True, world_readable=True, theme='white')

Sentiment_df = pd.DataFrame(twt. Sentiment_label.value_counts().reset_index())

Sentiment_df.columns = ['Sentiment', 'Count']

Sentiment_df = pd.DataFrame (Sentiment_df)

Sentiment_df['Percentage'] = 100* Sentiment_df['Count']/ Sentiment_df['Count'].sum()

Sentiment_Max = Sentiment_df.iloc[0,0] 

Sentiment_percent = str(round (Sentiment_df.iloc[0,2],2))

fig1 = Sentiment_df.iplot (kind='pie', labels = 'Sentiment', values = 'Count', textinfo='label+percent', title= 'Sentiment Analysis', world_readable=True, asFigure=True)

ply.offline.plot (fig1, filename="Sentiment.html")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 'Sentiment.html'

# %% [markdown]
# The graph clearly shows that 66.7% of total comments are neutral and that 28.3% of total comments are positive. Only about 5% are negative. From a business point of view, it's a pretty good result for Samsung.
#
# You can generate the following graphs to understand more about products.
#
# * Sentiment by date reveals at what point of time a product or company was not doing well.
#
# * Generate word cloud by a segment that tells you what positive and negative factors are for that product.
#
# As with the sentiment, you see what the emotion results look like.

# %% [markdown]
# ## Emotion Analysis
#
# As with the sentiment, you need to understand how the emotion to draw some significant conclusions. You predicted the emotion of every comment in earlier steps. Let's use that and generate charts to understand it better.
#
# A pie chart visualizes the emotions of the document. This graph is also generated using the cufflinks library.

# %%
import chart_studio.plotly as py

import plotly as ply

import cufflinks as cf

from plotly.graph_objs import *

from plotly.offline import *

init_notebook_mode (connected=True)

cf.set_config_file(offline=True, world_readable = True, theme='white')

Emotion_df = pd.DataFrame(twt.Emotion.value_counts().reset_index())

Emotion_df.columns = ['Emotion', 'Count']

Emotion_df = pd.DataFrame (Emotion_df)

Emotion_df['Percentage'] = 100* Emotion_df['Count']/ Emotion_df[ 'Count'].sum()

Emotion_Max = Emotion_df.iloc[0,0]

Emotion_percent = str(round(Emotion_df.iloc[0,2],2))

fig = Emotion_df.iplot (kind='pie', labels = 'Emotion', values ='Count', pull= .2, hole=.2, colorscale = 'reds', textposition='outside', colors=['red','green','purple', 'orange', 'blue', 'yellow', 'pink'], textinfo='label+percent', title= 'Emotion Analysis', world_readable=True, asFigure=True)

ply.offline.plot(fig, filename="Emotion.html")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 'Emotion.html'

# %% [markdown]
# The generated graph gives an emotional sense of the comments:40 % captured "disgust," 31.7% captured "joy," and the remaining captured anger,shame and guilt.
#
# The good thing is 31.7% of the customers are happy. But you need to dig deeper to understand why 40% of comments are disgusting. There is chance customer were neutral with sentiments and disgusted.
#
# To understand that, let's plot both sentiment and emotion on a single plot that answers all your questions.

# %% [markdown]
# ## Emotion and Sentiment Analysis
#
# The stacked bar plot is the combination of both emotion and sentiment. It consists of each emotion and the corresponding sentiment on that emotion and gives the value count of the emotions.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize': (11.7, 8.27)})

Result = pd.crosstab(twt.Emotion, twt.Sentiment_label)
Result = Result.reindex(sorted(Result.columns), axis=1)

plt = Result.plot.bar(stacked=True)

plt.legend(title='Sentiment_label')

plt.figure.savefig('Emotion_Sentiment_stacked.png', dpi=400)

# %% [markdown]
# ## Consumer Sentiment Analysis - Part B ends here.
